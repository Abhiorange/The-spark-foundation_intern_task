# %% [markdown]
# # GRIP NOV 2022
#
# ## AUTHOR: VADNAGARA ABHISHEK VIPULBHAI
#
# ## TASK-3: Perform Exploratory Data Analysis on dataset 'SampleSuperstore'

# %%
#step:1 importing libraries
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import numpy as np

# %%
#step:2 importing data
df=pd.read_csv(r"C:\Users\ABHISHEK\Desktop\sparks task\SampleSuperstore.csv")

# %%
#step:3 seeing data
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#step:4 getting data shape
df.shape
# Out:
# (9994, 13)

# %%
#step:5 getting columns
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#step:6 getting data statistics
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#step:7 getting data overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#step:8 getting count of null values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#step:9 getting count of unique values
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df.drop(['Postal Code','City','Country'],axis=1,inplace=True)
df
# Out:
#            Ship Mode    Segment       State Region         Category  \
# 0       Second Class   Consumer    Kentucky  South        Furniture
# 1       Second Class   Consumer    Kentucky  South        Furniture
# 2       Second Class  Corporate  California   West  Office Supplies
# 3     Standard Class   Consumer     Florida  South        Furniture
# 4     Standard Class   Consumer     Florida  South  Office Supplies
# ...              ...        ...         ...    ...              ...
# 9989    Second Class   Consumer     Florida  South        Furniture
# 9990  Standard Class   Consumer  California   West        Furniture
# 9991  Standard Class   Consumer  California   West       Technology
# 9992  Standard Class   Consumer  California   West  Office Supplies
# 9993    Second Class   Consumer  California   West  Office Supplies
#
#      Sub-Category     Sales  Quantity  Discount    Profit
# 0       Bookcases  261.9600         2      0.00   41.9136
# ...

# %%
df.duplicated().sum()
# Out:
# 137

# %%
df.drop_duplicates(keep="first",inplace=True)

# %%
sns.heatmap(df.corr(),xticklabels=df.corr().columns,yticklabels=df.corr().columns,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### here quantity and profit are positively correlated with sales and discount and profit are negatively correlated.

# %% [markdown]
# # Univariate Analysis

# %%
lenseg=len(df["Segment"])
lenseg
# Out:
# 9857

# %%
df["Segment"].value_counts()
# Out:
# Consumer       5107
# Corporate      2979
# Home Office    1771
# Name: Segment, dtype: int64

# %%
segper=(df["Segment"].value_counts()/lenseg)*100
segper
# Out:
# Consumer       51.810896
# Corporate      30.222177
# Home Office    17.966927
# Name: Segment, dtype: float64

# %%
segper.plot(kind="bar")
plt.xlabel("Segment")
plt.ylabel("Sales Percentage")
plt.title("Segment Analysis")
# Out:
# Text(0.5, 1.0, 'Segment Analysis')

# %% [markdown]
# ### home office segment is way behind than consumer segment.

# %%
df["State"].value_counts()
# Out:
# California              1934
# New York                1115
# Texas                    958
# Pennsylvania             581
# Washington               501
# Illinois                 488
# Ohio                     467
# Florida                  380
# Michigan                 253
# North Carolina           249
# Virginia                 222
# Arizona                  221
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  148
# Kentucky                 139
# Massachusetts            134
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(20,10))
df["State"].value_counts().plot(kind="bar")
plt.xlabel("States")
plt.ylabel("Sales")
plt.title("State Analysis")
# Out:
# Text(0.5, 1.0, 'State Analysis')

# %% [markdown]
# ### From califormia to wyoming sales are decreasing.

# %%
regper=(df["Region"].value_counts()/len(df["Region"]))*100
regper
# Out:
# West       31.723648
# East       28.669981
# Central    23.222076
# South      16.384295
# Name: Region, dtype: float64

# %%
regper.plot(kind="bar")
plt.xlabel("Region")
plt.ylabel("Sales Percentage")
plt.title("Region Analysis")
# Out:
# Text(0.5, 1.0, 'Region Analysis')

# %% [markdown]
# ### from above west region have highest sales.

# %%
catper=(df["Category"].value_counts()/len(df["Category"]))*100
catper
# Out:
# Office Supplies    60.058841
# Furniture          21.314802
# Technology         18.626357
# Name: Category, dtype: float64

# %%
catper.plot(kind="bar")
plt.xlabel("Category")
plt.ylabel("Sales Percentage")
plt.title("Category Analysis")
# Out:
# Text(0.5, 1.0, 'Category Analysis')

# %% [markdown]
# ### from above office supplies have highest sales.

# %%
subcatper=(df["Sub-Category"].value_counts()/len(df["Sub-Category"]))*100
subcatper
# Out:
# Binders        15.339353
# Paper          13.168307
# Furnishings     9.617531
# Phones          8.958101
# Storage         8.542153
# Art             7.994319
# Accessories     7.831998
# Chairs          6.178350
# Appliances      4.727605
# Labels          3.581211
# Tables          3.236279
# Envelopes       2.576849
# Bookcases       2.282642
# Fasteners       2.201481
# Supplies        1.927564
# Machines        1.156539
# Copiers         0.679720
# Name: Sub-Category, dtype: float64

# %%
subcatper.plot(kind="bar")
plt.xlabel("Subcategory")
plt.ylabel("Sales Percentage")
plt.title("Subcategory Analysis")
# Out:
# Text(0.5, 1.0, 'Subcategory Analysis')

# %% [markdown]
# ### from above binders, paper, furnishings, phones, storage, Art, Accessories make 75% sales.

# %%
from dataprep.eda import plot
plot(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15380/2967751027.py in <module>
# ----> 1 from dataprep.eda import plot
#       2 plot(df)
#
# ModuleNotFoundError: No module named 'dataprep'

# %% [markdown]
# # Bivariate Analysis

# %%
plot(df,"Region","Category")

# %% [markdown]
# ### from above office supplies have highest sales in all regions.

# %%
plt.figure(figsize=(20,10))
df.groupby("State")["Profit"].sum().plot(kind="bar")
plt.xlabel("State")
plt.ylabel("Profit")
plt.title("State Profit")
# Out:
# Text(0.5, 1.0, 'State Profit')

# %% [markdown]
# ### from above califormia and new york have highest profit whereas texas and ohio have highest losses.

# %%
plt.figure(figsize=(20,10))
df.groupby("State")["Sales"].sum().plot(kind="bar")
plt.xlabel("State")
plt.ylabel("Sales")
plt.title("State Sales")
# Out:
# Text(0.5, 1.0, 'State Sales')

# %% [markdown]
# ### from above califormia and new york have highest sales whereas north dakarto and west virginia have least sales.

# %%
plt.figure(figsize=(20,10))
df.groupby("State")["Discount"].sum().plot(kind="bar")
plt.xlabel("State")
plt.ylabel("Discount")
plt.title("State Discount")
# Out:
# Text(0.5, 1.0, 'State Discount')

# %% [markdown]
# ### from above Texas availed highest discount.

# %%
df.groupby("Region")[["Profit","Sales"]].sum().plot(kind="bar")
plt.xlabel("Region")
plt.ylabel("Profit and sales price")
plt.title("Region wise profit and sales")
# Out:
# Text(0.5, 1.0, 'Region wise profit and sales')

# %% [markdown]
# ### from above west region have highest profit whereas central region have lowest profit and west region have highest sales whereas south region have lowest sales.

# %%
df.groupby("Region")["Discount"].sum().plot(kind="bar")
plt.xlabel("Region")
plt.ylabel("Discount")
plt.title("Region wise discount")
# Out:
# Text(0.5, 1.0, 'Region wise discount')

# %% [markdown]
# ### from above central region availed highest discount.

# %%
plt.figure(figsize=(20,10))
df.groupby("Category")[["Profit","Sales"]].sum().plot(kind="bar")
plt.xlabel("Category")
plt.ylabel("Profit and sales price")
plt.title("Category wise profit and sales")
# Out:
# Text(0.5, 1.0, 'Category wise profit and sales')

# %% [markdown]
# ### technology brings highest sales and profit.

# %%
df.groupby("Category")["Discount"].sum().plot(kind="bar")
plt.xlabel("Category")
plt.ylabel("Discount")
plt.title("Category wise discount")
# Out:
# Text(0.5, 1.0, 'Category wise discount')

# %% [markdown]
# ### more discount is availed by office supplies.

# %%
plt.figure(figsize=(20,10))
df.groupby("Sub-Category")[["Profit","Sales"]].sum().plot(kind="bar")
plt.xlabel("Sub-category")
plt.ylabel("Profit and sales price")
plt.title("Sub-category wise profit and sales")
# Out:
# Text(0.5, 1.0, 'Sub-category wise profit and sales')

# %%
plt.figure(figsize=(20,10))
df.groupby("Sub-Category")["Discount"].sum().plot(kind="bar")
plt.xlabel("Sub-category")
plt.ylabel("Discount")
plt.title("Sub-category wise discount")
# Out:
# Text(0.5, 1.0, 'Sub-category wise discount')

# %%
disper=(df["Discount"].value_counts()/len(df["Discount"]))*100
disper
# Out:
# 0.00    47.976058
# 0.20    36.512123
# 0.70     4.230496
# 0.80     3.023232
# 0.30     2.282642
# 0.40     2.079740
# 0.60     1.379730
# 0.10     0.953637
# 0.50     0.669575
# 0.15     0.507254
# 0.32     0.273917
# 0.45     0.111596
# Name: Discount, dtype: float64

# %%
disper.plot(kind="bar")
plt.xlabel("Discount")
plt.ylabel("Percentage")
plt.title("Discount Analysis")
# Out:
# Text(0.5, 1.0, 'Discount Analysis')

# %% [markdown]
# ### from above approximately 47% is covered by no discount.

# %%
df.groupby("Discount")["Profit"].sum().plot(kind="bar")
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.title("Impact of discount on profit")
# Out:
# Text(0.5, 1.0, 'Impact of discount on profit')

# %% [markdown]
# ### from 30% onwards there is trend of loss.

# %%
df.groupby("Discount")["Sales"].sum().plot(kind="bar")
plt.xlabel("Discount")
plt.ylabel("Sales")
plt.title("Impact of discount on sales")
# Out:
# Text(0.5, 1.0, 'Impact of discount on sales')

# %% [markdown]
# ### from above 0% and 20% discounts have highest sales.

# %%
df.groupby("Segment")[["Profit","Sales"]].sum().plot(kind="bar")
plt.xlabel("Segment")
plt.ylabel("Profit and sales price")
plt.title("Segment wise profit and sales")
# Out:
# Text(0.5, 1.0, 'Segment wise profit and sales')

# %% [markdown]
# ### from above consumer segment have highest profit and sales.

# %%
df.groupby("Segment")["Discount"].sum().plot(kind="bar")
plt.xlabel("Segment")
plt.ylabel("Discount")
plt.title("Segment wise discount")
# Out:
# Text(0.5, 1.0, 'Segment wise discount')

# %% [markdown]
# ### from above consumer segment availed highest discount.

# %% [markdown]
# # Conclusion
#
# ## Weak Areas
#
# 1. States like Texas,Ohio,pennsylvania,illinios faced huge losses.
# 2. Region wise south has least number of sales.
# 3. In category office supplies availed most discount but technology have highest sales and profit.
# 4. In sub category bookcases and tables faced loses. so, manager needs to cut down discount from these 2 subcategories.
# 5. After analyzing discounts it is observed that till 20% discount there is profit but after that there is loss.
# 6. South Dakota, West Virginia have least sales.
# 7. In central region there is more discount but less profit so, manager needs to cut down profit for central region.
# 8. In sub category fasteners,labels,envelopes need more sales as currently with respect to current sales their profit is good.so, if more sales would be there then profit would go high.
